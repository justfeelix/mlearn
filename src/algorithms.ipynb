# %% [markdown]
# # Python + Algorithms Practice Scaffold
#
# Use this notebook as your step-by-step practice companion for src/algorithms.py.
#
# Rule: implement one Core task first, then test it, then move to Stretch and Mastery.

# %%
# Setup imports and make sure src is importable
import os
import sys
from pathlib import Path

ROOT = Path.cwd()
if (ROOT / 'algorithms.py').exists():
    pass
elif (ROOT / 'src' / 'algorithms.py').exists():
    sys.path.insert(0, str(ROOT / 'src'))
else:
    sys.path.insert(0, str(ROOT))

import numpy as np
import algorithms as alg

print('Loaded algorithms from:', Path(alg.__file__).resolve())

# %% [markdown]
# ## Phase Index
# 1. Python Foundations
# 2. Object-Oriented Programming
# 3. Data Structures
# 4. Sorting and Searching
# 5. Recursion and Number Theory
# 6. Graphs and Dynamic Programming
# 7. Advanced Algorithms
# 8. Machine Learning Prep
# 9. Testing, Benchmarking, Reflection

# %% [markdown]
# ## Phase 1: Python Foundations
# Practice targets:
# - basic_data_types()
# - control_flow()
# - functions_and_scope()
# - exceptions_and_assertions()

# %%
# TODO: Fill this with your Phase 1 experiments
# - Compare mutability with id() for list vs tuple
# - Build a small grading rule with if/elif/else
# - Write one pure and one impure function
# - Raise and catch one custom exception

# %% [markdown]
# ## Phase 2: Object-Oriented Programming
# Practice targets:
# - Person / Student
# - EncapsulatedClass
# - Animal polymorphism

# %%
# TODO: OOP drills
# 1) Instantiate Person and Student
# 2) Add __repr__ in algorithms.py and verify here
# 3) Practice polymorphism with list[Animal]

# %% [markdown]
# ## Phase 3: Data Structures
# Practice targets:
# - linked_list()
# - stack()
# - queue()
# - hash_table()
# - binary_search_tree()

# %%
# TODO: Data structure checkpoints
results = {
    'linked_list': 'pending',
    'stack': 'pending',
    'queue': 'pending',
    'hash_table': 'pending',
    'binary_search_tree': 'pending',
}
results

# %% [markdown]
# ## Phase 4: Sorting and Searching
# Practice targets:
# - insertion_sort, quick_sort, bubble_sort, merge_sort, heap_sort, selection_sort
# - linear_search, binary_search

# %%
# TODO: build your sorting and searching test harness
sample = [9, 4, 1, 7, 3, 8, 2, 6, 5]

# %% [markdown]
# ## Phase 5: Recursion and Number Theory
# Practice targets:
# - fibonacci
# - factorial
# - gcd, lcm
# - is_prime

# %%
# TODO: run recursive and iterative comparisons
test_values = [0, 1, 2, 5, 10]

# %% [markdown]
# ## Phase 6: Graphs and Dynamic Programming
# Practice targets:
# - dijkstra
# - a_star
# - knapsack
# - longest_common_subsequence

# %%
# TODO: graph and DP mini inputs
graph = {
    'A': {'B': 2, 'C': 5},
    'B': {'A': 2, 'C': 1, 'D': 4},
    'C': {'A': 5, 'B': 1, 'D': 1},
    'D': {'B': 4, 'C': 1}
}

# %% [markdown]
# ## Phase 7: Advanced Algorithms
# Practice targets:
# - radix_sort, counting_sort, bucket_sort
# - prim_mst, kruskal_mst, bellman_ford
#
# Capstone for advanced topics is provided in a separate notebook file.

# %%
# TODO: advanced algorithm scratch area

# %% [markdown]
# ## Phase 8: Machine Learning Prep
# Focus on from-scratch foundations before high-level libraries:
# - dot product and matrix multiplication
# - gradient descent
# - train/test split
# - confusion matrix and F1

# %%
# TODO: manual ML foundations
# - manual_dot(a, b)
# - manual_matmul(A, B)
# - gradient_descent_step(w, x, y, lr)

# %% [markdown]
# ## Phase 9: Testing, Benchmarking, Reflection
# Goal:
# - write repeatable checks
# - measure performance trends
# - document lessons learned

# %%
# TODO: tiny benchmark template
import time

def benchmark(fn, data, repeats=5):
    times = []
    for _ in range(repeats):
        t0 = time.perf_counter()
        fn(data.copy() if hasattr(data, 'copy') else data)
        times.append(time.perf_counter() - t0)
    return min(times), sum(times) / len(times)

# %% [markdown]
# ## Next Steps
# - Continue with the advanced capstone notebook: src/advanced_algorithms_capstone.ipynb
# - Keep this notebook for focused phase drills and quick experiments.

# %% [markdown]
# ## Section 1: Python Foundations

# %% [markdown]
# ### basic_data_types()
# - Core: int, float, str, list, tuple, set, dict examples; one operation per type; print types/values.
# - Stretch: mutability vs immutability with before/after id values; converter from list of tuples to dict.
# - Mastery: manual deep copy for nested lists without copy module; explain where shallow copy fails.

# %%
#TODO

# %% [markdown]
# ### control_flow()
# - Core: grading rule with if/elif/else; for and while loops producing same result; intentional break and continue.
# - Stretch: mini menu loop with quit command; validate predefined user-like input.
# - Mastery: simulate finite-state machine with loop and conditions.

# %%
#TODO

# %% [markdown]
# ### functions_and_scope()
# - Core: pure and impure functions; positional/keyword/default args; local vs global scope.
# - Stretch: args and kwargs examples; higher-order function.
# - Mastery: manual decorator for timing or logging.

# %%
#TODO

# %% [markdown]
# ### exceptions_and_assertions()
# - Core: raise and catch ValueError; use assertions for preconditions.
# - Stretch: custom exception class used in validation.
# - Mastery: robust error strategy for one full section.

# %%
#TODO

# %% [markdown]
# ## Section 2: OOP and Design Task Matrix
#
# ### phase_1_oop_core
# - Create `Book` class with constructor and methods.
# - Add class/staticmethods and properties.
# - Practice inheritance (`Animal` -> `Dog`).
#
# ### phase_2_oop_practice
# - Mini banking system with `Account` subclasses.
# - Inventory model with encapsulation.
# - Employee hierarchy with polymorphic pay calculation.
#
# ### phase_3_design_principles
# - Refactor a script into SRP-focused classes.
# - Replace conditionals with polymorphism.
# - Add dependency injection for testability.
#
# ### phase_4_patterns_intro
# - Factory for object creation.
# - Strategy for interchangeable algorithms.
# - Observer for event updates.

# %% [markdown]
# ## Section 3: Data Structures Task Matrix
#
# ### phase_1_arrays_lists
# - Dynamic array append/pop simulation.
# - Sliding window max sum.
# - Two-pointer pair sum and variants.
#
# ### phase_2_linked_structures
# - Singly linked list operations.
# - Reverse linked list iterative and recursive.
# - Detect cycle in linked list.
#
# ### phase_3_stacks_queues
# - Stack with list and with linked nodes.
# - Queue and deque implementations.
# - Parentheses validator using stack.
#
# ### phase_4_hash_and_sets
# - Simple hash map with chaining.
# - Frequency counter patterns.
# - LRU cache concept implementation.

# %% [markdown]
# ## Section 4: Searching and Sorting Task Matrix
#
# ### phase_1_searching
# - Implement linear search and binary search.
# - Binary search variants (first/last occurrence).
# - Search in rotated sorted array.
#
# ### phase_2_sorting_core
# - Implement bubble, selection, insertion sort.
# - Merge sort with merge helper.
# - Quick sort with partition logic.
#
# ### phase_3_sorting_advanced
# - Heap sort from scratch.
# - Counting sort and radix sort.
# - Stability experiments across sorts.
#
# ### phase_4_analysis
# - Benchmark all sorting algorithms.
# - Plot empirical runtime vs n.
# - Compare to Python built-in sort as reference.

# %% [markdown]
# ## Section 5: Recursion and Number Theory Task Matrix
#
# ### phase_1_recursion_core
# - Factorial and Fibonacci (recursive + memoized).
# - Tower of Hanoi move generator.
# - Recursive permutation generator.
#
# ### phase_2_number_theory
# - Euclidean GCD and extended GCD.
# - Sieve of Eratosthenes.
# - Fast modular exponentiation.
#
# ### phase_3_backtracking
# - N-Queens solver.
# - Sudoku backtracking skeleton.
# - Subset sum backtracking with pruning.

# %% [markdown]
# ## Section 6: Graphs and Dynamic Programming Task Matrix
#
# ### phase_1_graph_representation
# - Build adjacency list from edge list.
# - Convert adjacency list to matrix.
# - Directed vs undirected graph utilities.
#
# ### phase_2_graph_traversal
# - BFS shortest path in unweighted graph.
# - DFS recursive and iterative versions.
# - Connected components counting.
#
# ### phase_3_shortest_paths
# - Dijkstra implementation with priority queue.
# - Path reconstruction from parent map.
# - Compare BFS vs Dijkstra on weighted/unweighted.
#
# ### phase_4_dynamic_programming
# - 0/1 knapsack DP table and optimized version.
# - Longest increasing subsequence.
# - Coin change minimum coins + combinations.
#
# ### phase_5_dp_principles
# - Top-down memo vs bottom-up version of same problem.
# - State design exercise: define state/transition/base for 3 tasks.

# %% [markdown]
# ## Section 7: Advanced Algorithms Task Matrix
#
# ### phase_1_string_algorithms
# - KMP prefix table and search.
# - Rabin-Karp rolling hash.
# - Trie-based prefix query system.
#
# ### phase_2_dynamic_programming_advanced
# - Matrix chain multiplication DP.
# - Edit distance DP.
# - Weighted interval scheduling DP.
#
# ### phase_3_graph_advanced
# - Bellman-Ford with negative cycle detection.
# - Floyd-Warshall all-pairs shortest paths.
# - SCC detection (Kosaraju or Tarjan).
#
# ### phase_4_design_patterns
# - Strategy pattern for interchangeable algorithms.
# - Observer pattern for state update simulation.
# - Singleton config manager (thread-safe bonus).

# %% [markdown]
# ## Section 8: Machine Learning Prep Task Matrix
#
# ### phase_1_math
# - Manual dot product and matrix multiplication.
# - Gradient derivation for simple linear regression.
# - Gradient descent loop without sklearn.
#
# ### phase_2_models
# - Linear regression from scratch.
# - Logistic regression from scratch.
# - k-NN from scratch.
# - Decision tree split criterion implementation.
#
# ### phase_3_evaluation
# - Train/test split utility.
# - Confusion matrix and F1 from scratch.
# - k-fold cross-validation utility.
#
# ### phase_4_notebook_projects
# - Iris end-to-end classification.
# - House price mini regression project.
# - Error analysis and feature debugging notebook.

# %% [markdown]
# ## Section 9: Testing, Profiling, Reflection
#
# ### testing_and_benchmarking_tasks()
# - Core: tests for empty, single, duplicates, sorted, reverse sorted inputs.
# - Stretch: randomized tests with reproducible seeds.
# - Mastery: asymptotic benchmarking and postmortems.

# %%
# Universal execution runner for completed functions
import importlib
import traceback
import sys
from pathlib import Path

ROOT = Path.cwd()
if (ROOT / 'src' / 'algorithms.py').exists():
    sys.path.insert(0, str(ROOT / 'src'))
elif (ROOT / 'algorithms.py').exists():
    sys.path.insert(0, str(ROOT))

def load_alg():
    import algorithms as alg
    return importlib.reload(alg)

alg = load_alg()

sample_calls = {
    'basic_data_types': lambda: alg.basic_data_types(),
    'control_flow': lambda: alg.control_flow(),
    'functions_and_scope': lambda: alg.functions_and_scope(),
    'exceptions_and_assertions': lambda: alg.exceptions_and_assertions(),
    'linked_list': lambda: alg.linked_list(),
    'stack': lambda: alg.stack(),
    'queue': lambda: alg.queue(),
    'hash_table': lambda: alg.hash_table(),
    'binary_search_tree': lambda: alg.binary_search_tree(),
    'insertion_sort': lambda: alg.insertion_sort([9, 4, 1, 7, 3]),
    'quick_sort': lambda: alg.quick_sort([9, 4, 1, 7, 3]),
    'bubble_sort': lambda: alg.bubble_sort([9, 4, 1, 7, 3]),
    'merge_sort': lambda: alg.merge_sort([9, 4, 1, 7, 3]),
    'heap_sort': lambda: alg.heap_sort([9, 4, 1, 7, 3]),
    'selection_sort': lambda: alg.selection_sort([9, 4, 1, 7, 3]),
    'sorted_array': lambda: alg.sorted_array([9, 4, 1, 7, 3]),
    'binary_search': lambda: alg.binary_search([1, 3, 4, 7, 9], 7),
    'linear_search': lambda: alg.linear_search([9, 4, 1, 7, 3], 7),
    'fibonacci': lambda: alg.fibonacci(10),
    'factorial': lambda: alg.factorial(6),
    'gcd': lambda: alg.gcd(84, 18),
    'lcm': lambda: alg.lcm(21, 6),
    'is_prime': lambda: alg.is_prime(97),
    'dijkstra': lambda: alg.dijkstra({'A': {'B': 2}, 'B': {'A': 2}}, 'A'),
    'a_star': lambda: alg.a_star({'A': {'B': 2}, 'B': {'A': 2}}, 'A', 'B'),
    'knapsack': lambda: alg.knapsack([2, 3, 4], [4, 5, 7], 5),
    'longest_common_subsequence': lambda: alg.longest_common_subsequence('ABCD', 'AEBD'),
    'radix_sort': lambda: alg.radix_sort([170, 45, 75, 90, 802, 24, 2, 66]),
    'counting_sort': lambda: alg.counting_sort([170, 45, 75, 90], 1),
    'bucket_sort': lambda: alg.bucket_sort([0.42, 0.32, 0.23, 0.52]),
    'prim_mst': lambda: alg.prim_mst({'A': {'B': 1}, 'B': {'A': 1}}),
    'kruskal_mst': lambda: alg.kruskal_mst({'A': {'B': 1}, 'B': {'A': 1}}),
    'bellman_ford': lambda: alg.bellman_ford({'A': {'B': 1}, 'B': {'A': 1}}, 'A'),
    'testing_and_benchmarking_tasks': lambda: alg.testing_and_benchmarking_tasks(),
}

function_to_run = 'insertion_sort'

try:
    result = sample_calls[function_to_run]()
    print('Function:', function_to_run)
    print('Result:', result)
except Exception:
    print('Execution failed for', function_to_run)
    traceback.print_exc()

# %%
# OOP quick checker cell
import importlib
import traceback
import sys
from pathlib import Path

ROOT = Path.cwd()
if (ROOT / 'src' / 'algorithms.py').exists():
    sys.path.insert(0, str(ROOT / 'src'))
elif (ROOT / 'algorithms.py').exists():
    sys.path.insert(0, str(ROOT))

import algorithms as alg
alg = importlib.reload(alg)

try:
    p = alg.Person('Ada', 28)
    s = alg.Student('Linus', 21, 'S1001')
    p.display_info()
    print('Student ID:', getattr(s, 'student_id', None))
    print('Encapsulated value:', alg.EncapsulatedClass(10).get_value())
    print('Polymorphism:', alg.Dog().speak(), alg.Cat().speak())
except Exception:
    traceback.print_exc()
